# %%
import os
import json
import random
import numpy as np
import pandas as pd
import torch
import matplotlib.pyplot as plt
import seaborn as sns
import umap.umap_ as umap
from sentence_transformers import SentenceTransformer
from mpl_toolkits.mplot3d import Axes3D
import imageio

# Define the root directory and category folders
root_dir = './Thesis Data'
categories = {
    'Supreme Court': 'Supreme Court Jurisprudence',
    'Republic Acts': 'Republic Acts',
    'Commonwealth Acts': 'Commonwealth Acts',
    'Batas Pambata': 'Batas Pambata',
    'Acts': 'Acts'
}

# Define the sample sizes for each category for a total of Approx 1500 documents
sample_sizes = {
    'Supreme Court': 1059,
    'Republic Acts': 405,
    'Commonwealth Acts': 4,
    'Batas Pambata': 30,
    'Acts': 11
}

# %%
# Function to load and sample JSON files from a directory, including subdirectories
def sample_files_from_directory(directory, sample_size):
    files = []
    for root, _, filenames in os.walk(directory):
        files.extend([os.path.join(root, f) for f in filenames if f.endswith('.json')])
        
    sampled_files = random.sample(files, sample_size)
    data_list = []
    for file in sampled_files:
        with open(file, 'r') as f:
            data = json.load(f)
            if 'text' in data:
                data_list.append({
                    'text': data['text'],
                    'category': os.path.basename(directory)
                })
    return data_list

# %%
# Sample data from each category
sampled_data = []
for category, folder in categories.items():
    category_dir = os.path.join(root_dir, folder)
    sample_size = sample_sizes[category]
    sampled_data.extend(sample_files_from_directory(category_dir, sample_size))

# Convert sampled data to a DataFrame for further processing
df = pd.DataFrame(sampled_data)

# Check if a GPU is available
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f'Using device: {device}')

# Generate embeddings using the Alibaba-NLP/gte-large-en-v1.5 model
model = SentenceTransformer('Alibaba-NLP/gte-large-en-v1.5', trust_remote_code=True)
model = model.to(device)
# Out:
# Using device: cuda
# D:\Anaconda3Updated\envs\pytorch_env\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(

# %%
df.head()
# Out:
#                                                 text  \
# 0  Under consideration is this petition for revie...
# 1  To entitle petitioner spouse to a declaration ...
# 2  Before the Court is a Petition for Review on C...
# 3  At bar is a Petition for Review on Certiorari ...
# 4  Before the Court is a Petition for Review on C...
#
#                       category
# 0  Supreme Court Jurisprudence
# 1  Supreme Court Jurisprudence
# 2  Supreme Court Jurisprudence
# 3  Supreme Court Jurisprudence
# 4  Supreme Court Jurisprudence

# %%
np.shape(df)
# Out:
# (1509, 2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1509 entries, 0 to 1508
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   text      1509 non-null   object
#  1   category  1509 non-null   object
# dtypes: object(2)
# memory usage: 23.7+ KB

# %%
df.to_csv('sample_data_umap.csv', index=False)

# %%
# Function to process and embed text chunks
# Recursive Chunking
from langchain.text_splitter import RecursiveCharacterTextSplitter
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=4000,  # Adjusted chunk size for mini-LM
    chunk_overlap=200,  # Adding some overlap to maintain context between chunks
    separators=["\n\n", "\n", "(?<=\. )", " "],
    length_function=len
)

# %%
def embed_text_chunks(text, model, device, doc_index, category):
    embeddings = []
    categories = []
    doc_indices = []
    # If text is a list of strings, join them into a single string
    if isinstance(text, list):
        text = ' '.join(text)
    if not isinstance(text, str):
        print(f'Skipping non-string entry at document {doc_index+1}')
        return embeddings, categories, doc_indices
    chunks = text_splitter.split_text(text)
    for chunk_index, chunk in enumerate(chunks):
        embedding = model.encode(chunk, convert_to_tensor=True, device=device)
        embeddings.append(embedding)
        categories.append(category)  # Assign the same category to all chunks of the document
        doc_indices.append(doc_index)
        print(f'Embedded chunk {chunk_index+1}/{len(chunks)} of document {doc_index+1}/{len(df)}')
    return embeddings, categories, doc_indices

# Initialize lists to store embeddings, categories, and document indices
all_embeddings = []
all_categories = []
all_doc_indices = []

# Process documents
for doc_index in range(len(df['text'])):
    text = df['text'].iloc[doc_index]
    category = df['category'].iloc[doc_index]  # Get the category of the document
    chunk_embeddings, chunk_categories, chunk_doc_indices = embed_text_chunks(text, model, device, doc_index, category)
    all_embeddings.extend(chunk_embeddings)
    all_categories.extend(chunk_categories)
    all_doc_indices.extend(chunk_doc_indices)

# Convert embeddings to numpy arrays and check shapes
numpy_embeddings = []
for i, embedding in enumerate(all_embeddings):
    numpy_embedding = embedding.cpu().numpy()
    if i == 0:
        embedding_size = numpy_embedding.shape[0]
    if numpy_embedding.shape[0] != embedding_size:
        raise ValueError(f"Embedding at index {i} has incorrect shape: {numpy_embedding.shape}")
    numpy_embeddings.append(numpy_embedding)

# Create a DataFrame to store the embeddings, categories, and document indices
embeddings_df = pd.DataFrame({
    'embedding': numpy_embeddings,
    'doc_index': all_doc_indices,
    'category': all_categories
})

# Verify the dimensions of the embeddings
print(f"All document embeddings have size: {embedding_size}")
# Out:
# Embedded chunk 1/4 of document 1/1509
# Embedded chunk 2/4 of document 1/1509
# Embedded chunk 3/4 of document 1/1509
# Embedded chunk 4/4 of document 1/1509
# Embedded chunk 1/7 of document 2/1509
# Embedded chunk 2/7 of document 2/1509
# Embedded chunk 3/7 of document 2/1509
# Embedded chunk 4/7 of document 2/1509
# Embedded chunk 5/7 of document 2/1509
# Embedded chunk 6/7 of document 2/1509
# Embedded chunk 7/7 of document 2/1509
# Embedded chunk 1/6 of document 3/1509
# Embedded chunk 2/6 of document 3/1509
# Embedded chunk 3/6 of document 3/1509
# Embedded chunk 4/6 of document 3/1509
# Embedded chunk 5/6 of document 3/1509
# Embedded chunk 6/6 of document 3/1509
# Embedded chunk 1/4 of document 4/1509
# Embedded chunk 2/4 of document 4/1509
# Embedded chunk 3/4 of document 4/1509
# Embedded chunk 4/4 of document 4/1509
# Embedded chunk 1/12 of document 5/1509
# Embedded chunk 2/12 of document 5/1509
# Embedded chunk 3/12 of document 5/1509
# Embedded chunk 4/12 of document 5/1509
# Embedded chunk 5/12 of document 5/1509
# Embedded chunk 6/12 of document 5/1509
# Embedded chunk 7/12 of document 5/1509
# Embedded chunk 8/12 of document 5/1509
# Embedded chunk 9/12 of document 5/1509
# Embedded chunk 10/12 of document 5/1509
# Embedded chunk 11/12 of document 5/1509
# Embedded chunk 12/12 of document 5/1509
# Embedded chunk 1/8 of document 6/1509
# Embedded chunk 2/8 of document 6/1509
# Embedded chunk 3/8 of document 6/1509
# Embedded chunk 4/8 of document 6/1509
# Embedded chunk 5/8 of document 6/1509
# Embedded chunk 6/8 of document 6/1509
# Embedded chunk 7/8 of document 6/1509
# Embedded chunk 8/8 of document 6/1509
# Embedded chunk 1/6 of document 7/1509
# Embedded chunk 2/6 of document 7/1509
# Embedded chunk 3/6 of document 7/1509
# Embedded chunk 4/6 of document 7/1509
# Embedded chunk 5/6 of document 7/1509
# Embedded chunk 6/6 of document 7/1509
# Embedded chunk 1/7 of document 8/1509
# Embedded chunk 2/7 of document 8/1509
# Embedded chunk 3/7 of document 8/1509
# Embedded chunk 4/7 of document 8/1509
# Embedded chunk 5/7 of document 8/1509
# Embedded chunk 6/7 of document 8/1509
# Embedded chunk 7/7 of document 8/1509
# Embedded chunk 1/6 of document 9/1509
# Embedded chunk 2/6 of document 9/1509
# Embedded chunk 3/6 of document 9/1509
# Embedded chunk 4/6 of document 9/1509
# Embedded chunk 5/6 of document 9/1509
# Embedded chunk 6/6 of document 9/1509
# Embedded chunk 1/7 of document 10/1509
# Embedded chunk 2/7 of document 10/1509
# Embedded chunk 3/7 of document 10/1509
# Embedded chunk 4/7 of document 10/1509
# Embedded chunk 5/7 of document 10/1509
# Embedded chunk 6/7 of document 10/1509
# Embedded chunk 7/7 of document 10/1509
# Embedded chunk 1/7 of document 11/1509
# Embedded chunk 2/7 of document 11/1509
# Embedded chunk 3/7 of document 11/1509
# Embedded chunk 4/7 of document 11/1509
# Embedded chunk 5/7 of document 11/1509
# Embedded chunk 6/7 of document 11/1509
# Embedded chunk 7/7 of document 11/1509
# Embedded chunk 1/2 of document 12/1509
# Embedded chunk 2/2 of document 12/1509
# Embedded chunk 1/14 of document 13/1509
# Embedded chunk 2/14 of document 13/1509
# Embedded chunk 3/14 of document 13/1509
# Embedded chunk 4/14 of document 13/1509
# Embedded chunk 5/14 of document 13/1509
# Embedded chunk 6/14 of document 13/1509
# Embedded chunk 7/14 of document 13/1509
# Embedded chunk 8/14 of document 13/1509
# Embedded chunk 9/14 of document 13/1509
# Embedded chunk 10/14 of document 13/1509
# Embedded chunk 11/14 of document 13/1509
# Embedded chunk 12/14 of document 13/1509
# Embedded chunk 13/14 of document 13/1509
# Embedded chunk 14/14 of document 13/1509
# Embedded chunk 1/4 of document 14/1509
# Embedded chunk 2/4 of document 14/1509
# Embedded chunk 3/4 of document 14/1509
# Embedded chunk 4/4 of document 14/1509
# Embedded chunk 1/5 of document 15/1509
# Embedded chunk 2/5 of document 15/1509
# Embedded chunk 3/5 of document 15/1509
# Embedded chunk 4/5 of document 15/1509
# Embedded chunk 5/5 of document 15/1509
# Embedded chunk 1/6 of document 16/1509
# Embedded chunk 2/6 of document 16/1509
# Embedded chunk 3/6 of document 16/1509
# Embedded chunk 4/6 of document 16/1509
# Embedded chunk 5/6 of document 16/1509
# Embedded chunk 6/6 of document 16/1509
# Embedded chunk 1/4 of document 17/1509
# Embedded chunk 2/4 of document 17/1509
# Embedded chunk 3/4 of document 17/1509
# Embedded chunk 4/4 of document 17/1509
# Embedded chunk 1/7 of document 18/1509
# Embedded chunk 2/7 of document 18/1509
# Embedded chunk 3/7 of document 18/1509
# Embedded chunk 4/7 of document 18/1509
# Embedded chunk 5/7 of document 18/1509
# Embedded chunk 6/7 of document 18/1509
# Embedded chunk 7/7 of document 18/1509
# Embedded chunk 1/13 of document 19/1509
# Embedded chunk 2/13 of document 19/1509
# Embedded chunk 3/13 of document 19/1509
# Embedded chunk 4/13 of document 19/1509
# Embedded chunk 5/13 of document 19/1509
# Embedded chunk 6/13 of document 19/1509
# Embedded chunk 7/13 of document 19/1509
# Embedded chunk 8/13 of document 19/1509
# Embedded chunk 9/13 of document 19/1509
# Embedded chunk 10/13 of document 19/1509
# Embedded chunk 11/13 of document 19/1509
# Embedded chunk 12/13 of document 19/1509
# Embedded chunk 13/13 of document 19/1509
# Embedded chunk 1/6 of document 20/1509
# Embedded chunk 2/6 of document 20/1509
# Embedded chunk 3/6 of document 20/1509
# Embedded chunk 4/6 of document 20/1509
# Embedded chunk 5/6 of document 20/1509
# Embedded chunk 6/6 of document 20/1509
# Embedded chunk 1/4 of document 21/1509
# Embedded chunk 2/4 of document 21/1509
# Embedded chunk 3/4 of document 21/1509
# Embedded chunk 4/4 of document 21/1509
# Embedded chunk 1/6 of document 22/1509
# Embedded chunk 2/6 of document 22/1509
# Embedded chunk 3/6 of document 22/1509
# Embedded chunk 4/6 of document 22/1509
# Embedded chunk 5/6 of document 22/1509
# Embedded chunk 6/6 of document 22/1509
# Embedded chunk 1/6 of document 23/1509
# Embedded chunk 2/6 of document 23/1509
# Embedded chunk 3/6 of document 23/1509
# Embedded chunk 4/6 of document 23/1509
# Embedded chunk 5/6 of document 23/1509
# Embedded chunk 6/6 of document 23/1509
# Embedded chunk 1/8 of document 24/1509
# Embedded chunk 2/8 of document 24/1509
# Embedded chunk 3/8 of document 24/1509
# Embedded chunk 4/8 of document 24/1509
# Embedded chunk 5/8 of document 24/1509
# Embedded chunk 6/8 of document 24/1509
# Embedded chunk 7/8 of document 24/1509
# Embedded chunk 8/8 of document 24/1509
# Embedded chunk 1/16 of document 25/1509
# Embedded chunk 2/16 of document 25/1509
# Embedded chunk 3/16 of document 25/1509
# Embedded chunk 4/16 of document 25/1509
# Embedded chunk 5/16 of document 25/1509
# Embedded chunk 6/16 of document 25/1509
# Embedded chunk 7/16 of document 25/1509
# Embedded chunk 8/16 of document 25/1509
# Embedded chunk 9/16 of document 25/1509
# Embedded chunk 10/16 of document 25/1509
# Embedded chunk 11/16 of document 25/1509
# Embedded chunk 12/16 of document 25/1509
# Embedded chunk 13/16 of document 25/1509
# Embedded chunk 14/16 of document 25/1509
# Embedded chunk 15/16 of document 25/1509
# Embedded chunk 16/16 of document 25/1509
# Embedded chunk 1/1 of document 26/1509
# Embedded chunk 1/8 of document 27/1509
# Embedded chunk 2/8 of document 27/1509
# Embedded chunk 3/8 of document 27/1509
# Embedded chunk 4/8 of document 27/1509
# Embedded chunk 5/8 of document 27/1509
# Embedded chunk 6/8 of document 27/1509
# Embedded chunk 7/8 of document 27/1509
# Embedded chunk 8/8 of document 27/1509
# Embedded chunk 1/4 of document 28/1509
# Embedded chunk 2/4 of document 28/1509
# Embedded chunk 3/4 of document 28/1509
# Embedded chunk 4/4 of document 28/1509
# Embedded chunk 1/5 of document 29/1509
# Embedded chunk 2/5 of document 29/1509
# Embedded chunk 3/5 of document 29/1509
# Embedded chunk 4/5 of document 29/1509
# Embedded chunk 5/5 of document 29/1509
# Embedded chunk 2/4 of document 64/1509
# Embedded chunk 3/4 of document 64/1509
# Embedded chunk 4/4 of document 64/1509
# Embedded chunk 1/8 of document 65/1509
# Embedded chunk 2/8 of document 65/1509
# Embedded chunk 3/8 of document 65/1509
# Embedded chunk 4/8 of document 65/1509
# Embedded chunk 5/8 of document 65/1509
# Embedded chunk 6/8 of document 65/1509
# Embedded chunk 7/8 of document 65/1509
# Embedded chunk 8/8 of document 65/1509
# Embedded chunk 1/7 of document 66/1509
# Embedded chunk 2/7 of document 66/1509
# Embedded chunk 3/7 of document 66/1509
# Embedded chunk 4/7 of document 66/1509
# Embedded chunk 5/7 of document 66/1509
# Embedded chunk 6/7 of document 66/1509
# Embedded chunk 7/7 of document 66/1509
# Embedded chunk 1/4 of document 67/1509
# Embedded chunk 2/4 of document 67/1509
# Embedded chunk 3/4 of document 67/1509
# Embedded chunk 4/4 of document 67/1509
# Embedded chunk 1/5 of document 68/1509
# Embedded chunk 2/5 of document 68/1509
# Embedded chunk 3/5 of document 68/1509
# Embedded chunk 4/5 of document 68/1509
# Embedded chunk 5/5 of document 68/1509
# Embedded chunk 1/5 of document 69/1509
# Embedded chunk 2/5 of document 69/1509
# Embedded chunk 3/5 of document 69/1509
# Embedded chunk 4/5 of document 69/1509
# Embedded chunk 5/5 of document 69/1509
# Embedded chunk 1/6 of document 70/1509
# Embedded chunk 2/6 of document 70/1509
# Embedded chunk 3/6 of document 70/1509
# Embedded chunk 4/6 of document 70/1509
# Embedded chunk 5/6 of document 70/1509
# Embedded chunk 6/6 of document 70/1509
# Embedded chunk 1/6 of document 71/1509
# Embedded chunk 2/6 of document 71/1509
# Embedded chunk 3/6 of document 71/1509
# Embedded chunk 4/6 of document 71/1509
# Embedded chunk 5/6 of document 71/1509
# Embedded chunk 6/6 of document 71/1509
# Embedded chunk 1/5 of document 72/1509
# Embedded chunk 2/5 of document 72/1509
# Embedded chunk 3/5 of document 72/1509
# Embedded chunk 4/5 of document 72/1509
# Embedded chunk 5/5 of document 72/1509
# Embedded chunk 1/5 of document 73/1509
# Embedded chunk 2/5 of document 73/1509
# Embedded chunk 3/5 of document 73/1509
# Embedded chunk 4/5 of document 73/1509
# Embedded chunk 5/5 of document 73/1509
# Embedded chunk 1/5 of document 74/1509
# Embedded chunk 2/5 of document 74/1509
# Embedded chunk 3/5 of document 74/1509
# Embedded chunk 4/5 of document 74/1509
# Embedded chunk 5/5 of document 74/1509
# Embedded chunk 1/4 of document 75/1509
# Embedded chunk 2/4 of document 75/1509
# Embedded chunk 3/4 of document 75/1509
# Embedded chunk 4/4 of document 75/1509
# Embedded chunk 1/5 of document 76/1509
# Embedded chunk 2/5 of document 76/1509
# Embedded chunk 3/5 of document 76/1509
# Embedded chunk 4/5 of document 76/1509
# Embedded chunk 5/5 of document 76/1509
# Embedded chunk 1/15 of document 77/1509
# Embedded chunk 2/15 of document 77/1509
# Embedded chunk 3/15 of document 77/1509
# Embedded chunk 4/15 of document 77/1509
# Embedded chunk 5/15 of document 77/1509
# Embedded chunk 6/15 of document 77/1509
# Embedded chunk 7/15 of document 77/1509
# Embedded chunk 8/15 of document 77/1509
# Embedded chunk 9/15 of document 77/1509
# Embedded chunk 10/15 of document 77/1509
# Embedded chunk 11/15 of document 77/1509
# Embedded chunk 12/15 of document 77/1509
# Embedded chunk 13/15 of document 77/1509
# Embedded chunk 14/15 of document 77/1509
# Embedded chunk 15/15 of document 77/1509
# Embedded chunk 1/3 of document 78/1509
# Embedded chunk 2/3 of document 78/1509
# Embedded chunk 3/3 of document 78/1509
# Embedded chunk 1/10 of document 79/1509
# Embedded chunk 2/10 of document 79/1509
# Embedded chunk 3/10 of document 79/1509
# Embedded chunk 4/10 of document 79/1509
# Embedded chunk 5/10 of document 79/1509
# Embedded chunk 6/10 of document 79/1509
# Embedded chunk 7/10 of document 79/1509
# Embedded chunk 8/10 of document 79/1509
# Embedded chunk 9/10 of document 79/1509
# Embedded chunk 10/10 of document 79/1509
# Embedded chunk 1/16 of document 80/1509
# Embedded chunk 2/16 of document 80/1509
# Embedded chunk 3/16 of document 80/1509
# Embedded chunk 4/16 of document 80/1509
# Embedded chunk 5/16 of document 80/1509
# Embedded chunk 6/16 of document 80/1509
# Embedded chunk 7/16 of document 80/1509
# Embedded chunk 8/16 of document 80/1509
# Embedded chunk 9/16 of document 80/1509
# Embedded chunk 10/16 of document 80/1509
# Embedded chunk 11/16 of document 80/1509
# Embedded chunk 12/16 of document 80/1509
# Embedded chunk 13/16 of document 80/1509
# Embedded chunk 14/16 of document 80/1509
# Embedded chunk 15/16 of document 80/1509
# Embedded chunk 16/16 of document 80/1509
# Embedded chunk 1/14 of document 81/1509
# Embedded chunk 2/14 of document 81/1509
# Embedded chunk 3/14 of document 81/1509
# Embedded chunk 4/14 of document 81/1509
# Embedded chunk 5/14 of document 81/1509
# Embedded chunk 6/14 of document 81/1509
# Embedded chunk 7/14 of document 81/1509
# Embedded chunk 8/14 of document 81/1509
# Embedded chunk 9/14 of document 81/1509
# Embedded chunk 10/14 of document 81/1509
# Embedded chunk 11/14 of document 81/1509
# Embedded chunk 12/14 of document 81/1509
# Embedded chunk 13/14 of document 81/1509
# Embedded chunk 14/14 of document 81/1509
# Embedded chunk 1/5 of document 82/1509
# Embedded chunk 2/5 of document 82/1509
# Embedded chunk 3/5 of document 82/1509
# Embedded chunk 4/5 of document 82/1509
# Embedded chunk 5/5 of document 82/1509
# Embedded chunk 1/2 of document 83/1509
# Embedded chunk 2/2 of document 83/1509
# Embedded chunk 1/5 of document 84/1509
# Embedded chunk 2/5 of document 84/1509
# Embedded chunk 3/5 of document 84/1509
# Embedded chunk 4/5 of document 84/1509
# Embedded chunk 5/5 of document 84/1509
# Embedded chunk 1/4 of document 85/1509
# Embedded chunk 2/4 of document 85/1509
# Embedded chunk 3/4 of document 85/1509
# Embedded chunk 4/4 of document 85/1509
# Embedded chunk 1/7 of document 86/1509
# Embedded chunk 2/7 of document 86/1509
# Embedded chunk 3/7 of document 86/1509
# Embedded chunk 4/7 of document 86/1509
# Embedded chunk 5/7 of document 86/1509
# Embedded chunk 6/7 of document 86/1509
# Embedded chunk 2/2 of document 104/1509
# Embedded chunk 1/5 of document 105/1509
# Embedded chunk 2/5 of document 105/1509
# Embedded chunk 3/5 of document 105/1509
# Embedded chunk 4/5 of document 105/1509
# Embedded chunk 5/5 of document 105/1509
# Embedded chunk 1/6 of document 106/1509
# Embedded chunk 2/6 of document 106/1509
# Embedded chunk 3/6 of document 106/1509
# Embedded chunk 4/6 of document 106/1509
# Embedded chunk 5/6 of document 106/1509
# Embedded chunk 6/6 of document 106/1509
# Embedded chunk 1/5 of document 107/1509
# Embedded chunk 2/5 of document 107/1509
# Embedded chunk 3/5 of document 107/1509
# Embedded chunk 4/5 of document 107/1509
# Embedded chunk 5/5 of document 107/1509
# Embedded chunk 1/14 of document 108/1509
# Embedded chunk 2/14 of document 108/1509
# Embedded chunk 3/14 of document 108/1509
# Embedded chunk 4/14 of document 108/1509
# Embedded chunk 5/14 of document 108/1509
# Embedded chunk 6/14 of document 108/1509
# Embedded chunk 7/14 of document 108/1509
# Embedded chunk 8/14 of document 108/1509
# Embedded chunk 9/14 of document 108/1509
# Embedded chunk 10/14 of document 108/1509
# Embedded chunk 11/14 of document 108/1509
# Embedded chunk 12/14 of document 108/1509
# Embedded chunk 13/14 of document 108/1509
# Embedded chunk 14/14 of document 108/1509
# Embedded chunk 1/3 of document 109/1509
# Embedded chunk 2/3 of document 109/1509
# Embedded chunk 3/3 of document 109/1509
# Embedded chunk 1/3 of document 110/1509
# Embedded chunk 2/3 of document 110/1509
# Embedded chunk 3/3 of document 110/1509
# Embedded chunk 1/6 of document 111/1509
# Embedded chunk 2/6 of document 111/1509
# Embedded chunk 3/6 of document 111/1509
# Embedded chunk 4/6 of document 111/1509
# Embedded chunk 5/6 of document 111/1509
# Embedded chunk 6/6 of document 111/1509
# Embedded chunk 1/5 of document 112/1509
# Embedded chunk 2/5 of document 112/1509
# Embedded chunk 3/5 of document 112/1509
# Embedded chunk 4/5 of document 112/1509
# Embedded chunk 5/5 of document 112/1509
# Embedded chunk 1/8 of document 113/1509
# Embedded chunk 2/8 of document 113/1509
# Embedded chunk 3/8 of document 113/1509
# Embedded chunk 4/8 of document 113/1509
# Embedded chunk 5/8 of document 113/1509
# Embedded chunk 6/8 of document 113/1509
# Embedded chunk 7/8 of document 113/1509
# Embedded chunk 8/8 of document 113/1509
# Embedded chunk 1/9 of document 114/1509
# Embedded chunk 2/9 of document 114/1509
# Embedded chunk 3/9 of document 114/1509
# Embedded chunk 4/9 of document 114/1509
# Embedded chunk 5/9 of document 114/1509
# Embedded chunk 6/9 of document 114/1509
# Embedded chunk 7/9 of document 114/1509
# Embedded chunk 8/9 of document 114/1509
# Embedded chunk 9/9 of document 114/1509
# Embedded chunk 1/5 of document 115/1509
# Embedded chunk 2/5 of document 115/1509
# Embedded chunk 3/5 of document 115/1509
# Embedded chunk 4/5 of document 115/1509
# Embedded chunk 5/5 of document 115/1509
# Embedded chunk 1/10 of document 116/1509
# Embedded chunk 2/10 of document 116/1509
# Embedded chunk 3/10 of document 116/1509
# Embedded chunk 4/10 of document 116/1509
# Embedded chunk 3/9 of document 127/1509
# Embedded chunk 4/9 of document 127/1509
# Embedded chunk 5/9 of document 127/1509
# Embedded chunk 6/9 of document 127/1509
# Embedded chunk 7/9 of document 127/1509
# Embedded chunk 8/9 of document 127/1509
# Embedded chunk 9/9 of document 127/1509
# Embedded chunk 1/13 of document 128/1509
# Embedded chunk 2/13 of document 128/1509
# Embedded chunk 3/13 of document 128/1509
# Embedded chunk 4/13 of document 128/1509
# Embedded chunk 5/13 of document 128/1509
# Embedded chunk 6/13 of document 128/1509
# Embedded chunk 7/13 of document 128/1509
# Embedded chunk 8/13 of document 128/1509
# Embedded chunk 9/13 of document 128/1509
# Embedded chunk 10/13 of document 128/1509
# Embedded chunk 11/13 of document 128/1509
# Embedded chunk 12/13 of document 128/1509
# Embedded chunk 13/13 of document 128/1509
# Embedded chunk 1/5 of document 129/1509
# Embedded chunk 2/5 of document 129/1509
# Embedded chunk 3/5 of document 129/1509
# Embedded chunk 4/5 of document 129/1509
# Embedded chunk 5/5 of document 129/1509
# Embedded chunk 1/6 of document 130/1509
# Embedded chunk 2/6 of document 130/1509
# Embedded chunk 3/6 of document 130/1509
# Embedded chunk 4/6 of document 130/1509
# Embedded chunk 5/6 of document 130/1509
# Embedded chunk 6/6 of document 130/1509
# Embedded chunk 1/3 of document 131/1509
# Embedded chunk 2/3 of document 131/1509
# Embedded chunk 3/3 of document 131/1509
# Embedded chunk 1/3 of document 132/1509
# Embedded chunk 2/3 of document 132/1509
# Embedded chunk 3/3 of document 132/1509
# Embedded chunk 1/8 of document 133/1509
# Embedded chunk 2/8 of document 133/1509
# Embedded chunk 3/8 of document 133/1509
# Embedded chunk 4/8 of document 133/1509
# Embedded chunk 5/8 of document 133/1509
# Embedded chunk 6/8 of document 133/1509
# Embedded chunk 7/8 of document 133/1509
# Embedded chunk 8/8 of document 133/1509
# Embedded chunk 1/6 of document 134/1509
# Embedded chunk 2/6 of document 134/1509
# Embedded chunk 3/6 of document 134/1509
# Embedded chunk 4/6 of document 134/1509
# Embedded chunk 5/6 of document 134/1509
# Embedded chunk 6/6 of document 134/1509
# Embedded chunk 1/6 of document 135/1509
# Embedded chunk 2/6 of document 135/1509
# Embedded chunk 3/6 of document 135/1509
# Embedded chunk 4/6 of document 135/1509
# Embedded chunk 5/6 of document 135/1509
# Embedded chunk 6/6 of document 135/1509
# Embedded chunk 1/3 of document 136/1509
# Embedded chunk 2/3 of document 136/1509
# Embedded chunk 3/3 of document 136/1509
# Embedded chunk 1/4 of document 137/1509
# Embedded chunk 2/4 of document 137/1509
# Embedded chunk 3/4 of document 137/1509
# Embedded chunk 4/4 of document 137/1509
# Embedded chunk 1/10 of document 138/1509
# Embedded chunk 2/10 of document 138/1509
# Embedded chunk 3/10 of document 138/1509
# Embedded chunk 4/10 of document 138/1509
# Embedded chunk 5/10 of document 138/1509
# Embedded chunk 6/10 of document 138/1509
# Embedded chunk 7/10 of document 138/1509
# Embedded chunk 8/10 of document 138/1509
# Embedded chunk 9/10 of document 138/1509
# Embedded chunk 10/10 of document 138/1509
# Embedded chunk 1/7 of document 139/1509
# Embedded chunk 2/7 of document 139/1509
# Embedded chunk 3/7 of document 139/1509
# Embedded chunk 4/7 of document 139/1509
# Embedded chunk 5/7 of document 139/1509
# Embedded chunk 6/7 of document 139/1509
# Embedded chunk 7/7 of document 139/1509
# Embedded chunk 1/6 of document 140/1509
# Embedded chunk 2/6 of document 140/1509
# Embedded chunk 3/6 of document 140/1509
# Embedded chunk 4/6 of document 140/1509
# Embedded chunk 5/6 of document 140/1509
# Embedded chunk 6/6 of document 140/1509
# Embedded chunk 1/4 of document 141/1509
# Embedded chunk 2/4 of document 141/1509
# Embedded chunk 3/4 of document 141/1509
# Embedded chunk 4/4 of document 141/1509
# Embedded chunk 1/9 of document 142/1509
# Embedded chunk 2/9 of document 142/1509
# Embedded chunk 3/9 of document 142/1509
# Embedded chunk 4/9 of document 142/1509
# Embedded chunk 5/9 of document 142/1509
# Embedded chunk 6/9 of document 142/1509
# Embedded chunk 7/9 of document 142/1509
# Embedded chunk 8/9 of document 142/1509
# Embedded chunk 9/9 of document 142/1509
# Embedded chunk 1/5 of document 143/1509
# Embedded chunk 2/5 of document 143/1509
# Embedded chunk 3/5 of document 143/1509
# Embedded chunk 4/5 of document 143/1509
# Embedded chunk 5/5 of document 143/1509
# Embedded chunk 1/9 of document 144/1509
# Embedded chunk 2/9 of document 144/1509
# Embedded chunk 3/9 of document 144/1509
# Embedded chunk 4/9 of document 144/1509
# Embedded chunk 5/9 of document 144/1509
# Embedded chunk 6/9 of document 144/1509
# Embedded chunk 7/9 of document 144/1509
# Embedded chunk 8/9 of document 144/1509
# Embedded chunk 9/9 of document 144/1509
# Embedded chunk 1/4 of document 145/1509
# Embedded chunk 2/4 of document 145/1509
# Embedded chunk 3/4 of document 145/1509
# Embedded chunk 4/4 of document 145/1509
# Embedded chunk 1/3 of document 146/1509
# Embedded chunk 2/3 of document 146/1509
# Embedded chunk 3/3 of document 146/1509
# Embedded chunk 1/5 of document 147/1509
# Embedded chunk 2/5 of document 147/1509
# Embedded chunk 3/5 of document 147/1509
# Embedded chunk 4/5 of document 147/1509
# Embedded chunk 5/5 of document 147/1509
# Embedded chunk 1/2 of document 148/1509
# Embedded chunk 2/2 of document 148/1509
# Embedded chunk 1/6 of document 149/1509
# Embedded chunk 2/6 of document 149/1509
# Embedded chunk 3/6 of document 149/1509
# Embedded chunk 4/6 of document 149/1509
# Embedded chunk 5/6 of document 149/1509
# Embedded chunk 6/6 of document 149/1509
# Embedded chunk 1/4 of document 150/1509
# Embedded chunk 2/4 of document 150/1509
# Embedded chunk 3/4 of document 150/1509
# Embedded chunk 4/4 of document 150/1509
# Embedded chunk 1/5 of document 151/1509
# Embedded chunk 2/5 of document 151/1509
# Embedded chunk 3/5 of document 151/1509
# Embedded chunk 4/5 of document 151/1509
# Embedded chunk 5/5 of document 151/1509
# Embedded chunk 1/7 of document 152/1509
# Embedded chunk 2/7 of document 152/1509
# Embedded chunk 3/7 of document 152/1509
# Embedded chunk 4/7 of document 152/1509
# Embedded chunk 5/7 of document 152/1509
# Embedded chunk 9/12 of document 163/1509
# Embedded chunk 10/12 of document 163/1509
# Embedded chunk 11/12 of document 163/1509
# Embedded chunk 12/12 of document 163/1509
# Embedded chunk 1/2 of document 164/1509
# Embedded chunk 2/2 of document 164/1509
# Embedded chunk 1/8 of document 165/1509
# Embedded chunk 2/8 of document 165/1509
# Embedded chunk 3/8 of document 165/1509
# Embedded chunk 4/8 of document 165/1509
# Embedded chunk 5/8 of document 165/1509
# Embedded chunk 6/8 of document 165/1509
# Embedded chunk 7/8 of document 165/1509
# Embedded chunk 8/8 of document 165/1509
# Embedded chunk 1/17 of document 166/1509
# Embedded chunk 2/17 of document 166/1509
# Embedded chunk 3/17 of document 166/1509
# Embedded chunk 4/17 of document 166/1509
# Embedded chunk 5/17 of document 166/1509
# Embedded chunk 6/17 of document 166/1509
# Embedded chunk 7/17 of document 166/1509
# Embedded chunk 8/17 of document 166/1509
# Embedded chunk 9/17 of document 166/1509
# Embedded chunk 10/17 of document 166/1509
# Embedded chunk 11/17 of document 166/1509
# Embedded chunk 12/17 of document 166/1509
# Embedded chunk 13/17 of document 166/1509
# Embedded chunk 14/17 of document 166/1509
# Embedded chunk 15/17 of document 166/1509
# Embedded chunk 16/17 of document 166/1509
# Embedded chunk 17/17 of document 166/1509
# Embedded chunk 1/10 of document 167/1509
# Embedded chunk 2/10 of document 167/1509
# Embedded chunk 3/10 of document 167/1509
# Embedded chunk 4/10 of document 167/1509
# Embedded chunk 5/10 of document 167/1509
# Embedded chunk 6/10 of document 167/1509
# Embedded chunk 7/10 of document 167/1509
# Embedded chunk 8/10 of document 167/1509
# Embedded chunk 9/10 of document 167/1509
# Embedded chunk 10/10 of document 167/1509
# Embedded chunk 1/8 of document 168/1509
# Embedded chunk 2/8 of document 168/1509
# Embedded chunk 3/8 of document 168/1509
# Embedded chunk 4/8 of document 168/1509
# Embedded chunk 5/8 of document 168/1509
# Embedded chunk 6/8 of document 168/1509
# Embedded chunk 7/8 of document 168/1509
# Embedded chunk 8/8 of document 168/1509
# Embedded chunk 1/3 of document 169/1509
# ...
# Embedded chunk 9/18 of document 1339/1509
# Embedded chunk 10/18 of document 1339/1509
# Embedded chunk 11/18 of document 1339/1509
# Embedded chunk 12/18 of document 1339/1509
# Embedded chunk 13/18 of document 1339/1509
# Embedded chunk 14/18 of document 1339/1509
# Embedded chunk 15/18 of document 1339/1509
# Embedded chunk 16/18 of document 1339/1509
# Embedded chunk 17/18 of document 1339/1509
# Embedded chunk 18/18 of document 1339/1509
# Embedded chunk 1/2 of document 1340/1509
# Embedded chunk 2/2 of document 1340/1509
# Embedded chunk 1/1 of document 1341/1509
# Embedded chunk 1/1 of document 1342/1509
# Embedded chunk 1/1 of document 1343/1509
# Embedded chunk 1/3 of document 1344/1509
# Embedded chunk 2/3 of document 1344/1509
# Embedded chunk 3/3 of document 1344/1509
# Embedded chunk 1/1 of document 1345/1509
# Embedded chunk 1/1 of document 1346/1509
# Embedded chunk 1/1 of document 1347/1509
# Embedded chunk 1/1 of document 1348/1509
# Embedded chunk 1/1 of document 1349/1509
# Embedded chunk 1/1 of document 1350/1509
# Embedded chunk 1/2 of document 1351/1509
# Embedded chunk 2/2 of document 1351/1509
# Embedded chunk 1/13 of document 1352/1509
# Embedded chunk 2/13 of document 1352/1509
# Embedded chunk 3/13 of document 1352/1509
# Embedded chunk 4/13 of document 1352/1509
# Embedded chunk 5/13 of document 1352/1509
# Embedded chunk 6/13 of document 1352/1509
# Embedded chunk 7/13 of document 1352/1509
# Embedded chunk 8/13 of document 1352/1509
# Embedded chunk 9/13 of document 1352/1509
# Embedded chunk 10/13 of document 1352/1509
# Embedded chunk 11/13 of document 1352/1509
# Embedded chunk 12/13 of document 1352/1509
# Embedded chunk 13/13 of document 1352/1509
# Embedded chunk 1/1 of document 1353/1509
# Embedded chunk 1/7 of document 1354/1509
# Embedded chunk 2/7 of document 1354/1509
# Embedded chunk 3/7 of document 1354/1509
# Embedded chunk 4/7 of document 1354/1509
# Embedded chunk 5/7 of document 1354/1509
# Embedded chunk 6/7 of document 1354/1509
# Embedded chunk 7/7 of document 1354/1509
# Embedded chunk 1/2 of document 1355/1509
# Embedded chunk 2/2 of document 1355/1509
# Embedded chunk 1/4 of document 1356/1509
# Embedded chunk 2/4 of document 1356/1509
# Embedded chunk 3/4 of document 1356/1509
# Embedded chunk 4/4 of document 1356/1509
# Embedded chunk 1/1 of document 1357/1509
# Embedded chunk 1/6 of document 1358/1509
# Embedded chunk 2/6 of document 1358/1509
# Embedded chunk 3/6 of document 1358/1509
# Embedded chunk 4/6 of document 1358/1509
# Embedded chunk 5/6 of document 1358/1509
# Embedded chunk 6/6 of document 1358/1509
# Embedded chunk 1/1 of document 1359/1509
# Embedded chunk 1/2 of document 1360/1509
# Embedded chunk 2/2 of document 1360/1509
# Embedded chunk 1/1 of document 1361/1509
# Embedded chunk 1/1 of document 1362/1509
# Embedded chunk 1/1 of document 1363/1509
# Embedded chunk 1/1 of document 1364/1509
# Embedded chunk 1/1 of document 1365/1509
# Embedded chunk 1/4 of document 1366/1509
# Embedded chunk 2/4 of document 1366/1509
# Embedded chunk 3/4 of document 1366/1509
# Embedded chunk 4/4 of document 1366/1509
# Embedded chunk 1/1 of document 1367/1509
# Embedded chunk 1/1 of document 1368/1509
# Embedded chunk 1/1 of document 1369/1509
# Embedded chunk 1/3 of document 1370/1509
# Embedded chunk 2/3 of document 1370/1509
# Embedded chunk 3/3 of document 1370/1509
# Embedded chunk 1/1 of document 1371/1509
# Embedded chunk 1/1 of document 1372/1509
# Embedded chunk 1/1 of document 1373/1509
# Embedded chunk 1/2 of document 1374/1509
# Embedded chunk 2/2 of document 1374/1509
# Embedded chunk 1/1 of document 1375/1509
# Embedded chunk 1/1 of document 1376/1509
# Embedded chunk 1/3 of document 1377/1509
# Embedded chunk 2/3 of document 1377/1509
# Embedded chunk 3/3 of document 1377/1509
# Embedded chunk 1/1 of document 1378/1509
# Embedded chunk 1/4 of document 1379/1509
# Embedded chunk 2/4 of document 1379/1509
# Embedded chunk 3/4 of document 1379/1509
# Embedded chunk 4/4 of document 1379/1509
# Embedded chunk 25/32 of document 1391/1509
# Embedded chunk 26/32 of document 1391/1509
# Embedded chunk 27/32 of document 1391/1509
# Embedded chunk 28/32 of document 1391/1509
# Embedded chunk 29/32 of document 1391/1509
# Embedded chunk 30/32 of document 1391/1509
# Embedded chunk 31/32 of document 1391/1509
# Embedded chunk 32/32 of document 1391/1509
# Embedded chunk 1/3 of document 1392/1509
# Embedded chunk 2/3 of document 1392/1509
# Embedded chunk 3/3 of document 1392/1509
# Embedded chunk 1/1 of document 1393/1509
# Embedded chunk 1/1 of document 1394/1509
# Embedded chunk 1/1 of document 1395/1509
# Embedded chunk 1/2 of document 1396/1509
# Embedded chunk 2/2 of document 1396/1509
# Embedded chunk 1/1 of document 1397/1509
# Embedded chunk 1/1 of document 1398/1509
# Embedded chunk 1/1 of document 1399/1509
# Embedded chunk 1/25 of document 1400/1509
# Embedded chunk 2/25 of document 1400/1509
# Embedded chunk 3/25 of document 1400/1509
# Embedded chunk 4/25 of document 1400/1509
# Embedded chunk 5/25 of document 1400/1509
# Embedded chunk 6/25 of document 1400/1509
# Embedded chunk 7/25 of document 1400/1509
# Embedded chunk 8/25 of document 1400/1509
# Embedded chunk 9/25 of document 1400/1509
# Embedded chunk 10/25 of document 1400/1509
# Embedded chunk 11/25 of document 1400/1509
# Embedded chunk 12/25 of document 1400/1509
# Embedded chunk 13/25 of document 1400/1509
# Embedded chunk 14/25 of document 1400/1509
# Embedded chunk 15/25 of document 1400/1509
# Embedded chunk 16/25 of document 1400/1509
# Embedded chunk 17/25 of document 1400/1509
# Embedded chunk 18/25 of document 1400/1509
# Embedded chunk 19/25 of document 1400/1509
# Embedded chunk 20/25 of document 1400/1509
# Embedded chunk 21/25 of document 1400/1509
# Embedded chunk 22/25 of document 1400/1509
# Embedded chunk 23/25 of document 1400/1509
# Embedded chunk 24/25 of document 1400/1509
# Embedded chunk 25/25 of document 1400/1509
# Embedded chunk 1/1 of document 1401/1509
# Embedded chunk 1/1 of document 1402/1509
# Embedded chunk 1/1 of document 1403/1509
# Embedded chunk 1/1 of document 1404/1509
# Embedded chunk 1/1 of document 1405/1509
# Embedded chunk 1/1 of document 1406/1509
# Embedded chunk 1/1 of document 1407/1509
# Embedded chunk 1/1 of document 1408/1509
# Embedded chunk 1/1 of document 1409/1509
# Embedded chunk 1/1 of document 1410/1509
# Embedded chunk 1/1 of document 1411/1509
# Embedded chunk 1/1 of document 1412/1509
# Embedded chunk 1/1 of document 1413/1509
# Embedded chunk 1/1 of document 1414/1509
# Embedded chunk 1/4 of document 1415/1509
# Embedded chunk 2/4 of document 1415/1509
# Embedded chunk 3/4 of document 1415/1509
# Embedded chunk 4/4 of document 1415/1509
# Embedded chunk 1/1 of document 1416/1509
# Embedded chunk 1/1 of document 1417/1509
# Embedded chunk 1/1 of document 1418/1509
# Embedded chunk 1/1 of document 1419/1509
# Embedded chunk 1/1 of document 1420/1509
# Embedded chunk 1/30 of document 1421/1509
# Embedded chunk 2/30 of document 1421/1509
# Embedded chunk 3/30 of document 1421/1509
# Embedded chunk 4/30 of document 1421/1509
# Embedded chunk 5/30 of document 1421/1509
# Embedded chunk 6/30 of document 1421/1509
# Embedded chunk 7/30 of document 1421/1509
# Embedded chunk 8/30 of document 1421/1509
# Embedded chunk 9/30 of document 1421/1509
# Embedded chunk 10/30 of document 1421/1509
# Embedded chunk 11/30 of document 1421/1509
# Embedded chunk 12/30 of document 1421/1509
# Embedded chunk 13/30 of document 1421/1509
# Embedded chunk 14/30 of document 1421/1509
# Embedded chunk 15/30 of document 1421/1509
# Embedded chunk 16/30 of document 1421/1509
# Embedded chunk 17/30 of document 1421/1509
# Embedded chunk 18/30 of document 1421/1509
# Embedded chunk 19/30 of document 1421/1509
# Embedded chunk 20/30 of document 1421/1509
# Embedded chunk 21/30 of document 1421/1509
# Embedded chunk 22/30 of document 1421/1509
# Embedded chunk 23/30 of document 1421/1509
# Embedded chunk 24/30 of document 1421/1509
# Embedded chunk 25/30 of document 1421/1509
# Embedded chunk 26/30 of document 1421/1509
# Embedded chunk 27/30 of document 1421/1509
# Embedded chunk 28/30 of document 1421/1509
# Embedded chunk 29/30 of document 1421/1509
# Embedded chunk 30/30 of document 1421/1509
# Embedded chunk 1/1 of document 1422/1509
# Embedded chunk 1/4 of document 1423/1509
# Embedded chunk 2/4 of document 1423/1509
# Embedded chunk 3/4 of document 1423/1509
# Embedded chunk 4/4 of document 1423/1509
# Embedded chunk 1/1 of document 1424/1509
# Embedded chunk 1/1 of document 1425/1509
# Embedded chunk 1/1 of document 1426/1509
# Embedded chunk 1/1 of document 1427/1509
# Embedded chunk 1/4 of document 1428/1509
# Embedded chunk 2/4 of document 1428/1509
# Embedded chunk 3/4 of document 1428/1509
# Embedded chunk 4/4 of document 1428/1509
# Embedded chunk 1/1 of document 1429/1509
# Embedded chunk 1/5 of document 1430/1509
# Embedded chunk 2/5 of document 1430/1509
# Embedded chunk 3/5 of document 1430/1509
# Embedded chunk 4/5 of document 1430/1509
# Embedded chunk 5/5 of document 1430/1509
# Embedded chunk 1/1 of document 1431/1509
# Embedded chunk 1/1 of document 1432/1509
# Embedded chunk 1/1 of document 1433/1509
# Embedded chunk 1/1 of document 1434/1509
# Embedded chunk 1/1 of document 1435/1509
# Embedded chunk 1/1 of document 1436/1509
# Embedded chunk 1/1 of document 1437/1509
# Embedded chunk 1/1 of document 1438/1509
# Embedded chunk 1/1 of document 1439/1509
# Embedded chunk 1/1 of document 1440/1509
# Embedded chunk 1/1 of document 1441/1509
# Embedded chunk 1/1 of document 1442/1509
# Embedded chunk 1/1 of document 1443/1509
# Embedded chunk 1/1 of document 1444/1509
# Embedded chunk 1/1 of document 1445/1509
# Embedded chunk 1/1 of document 1446/1509
# Embedded chunk 1/1 of document 1447/1509
# Embedded chunk 1/1 of document 1448/1509
# Embedded chunk 1/1 of document 1449/1509
# Embedded chunk 1/1 of document 1450/1509
# Embedded chunk 1/1 of document 1451/1509
# Embedded chunk 1/1 of document 1452/1509
# Embedded chunk 1/4 of document 1453/1509
# Embedded chunk 2/4 of document 1453/1509
# Embedded chunk 3/4 of document 1453/1509
# Embedded chunk 4/4 of document 1453/1509
# Embedded chunk 1/1 of document 1454/1509
# Embedded chunk 1/1 of document 1455/1509
# Embedded chunk 1/1 of document 1456/1509
# Embedded chunk 1/1 of document 1457/1509
# Embedded chunk 1/1 of document 1458/1509
# Embedded chunk 1/1 of document 1459/1509
# Embedded chunk 1/1 of document 1460/1509
# Embedded chunk 1/1 of document 1461/1509
# Embedded chunk 1/11 of document 1462/1509
# Embedded chunk 2/11 of document 1462/1509
# Embedded chunk 3/11 of document 1462/1509
# Embedded chunk 4/11 of document 1462/1509
# Embedded chunk 5/11 of document 1462/1509
# Embedded chunk 6/11 of document 1462/1509
# Embedded chunk 7/11 of document 1462/1509
# Embedded chunk 8/11 of document 1462/1509
# Embedded chunk 9/11 of document 1462/1509
# Embedded chunk 10/11 of document 1462/1509
# Embedded chunk 11/11 of document 1462/1509
# Embedded chunk 1/5 of document 1463/1509
# Embedded chunk 2/5 of document 1463/1509
# Embedded chunk 3/5 of document 1463/1509
# Embedded chunk 4/5 of document 1463/1509
# Embedded chunk 5/5 of document 1463/1509
# Embedded chunk 1/1 of document 1464/1509
# Embedded chunk 1/2 of document 1465/1509
# Embedded chunk 2/2 of document 1465/1509
# Embedded chunk 1/1 of document 1466/1509
# Embedded chunk 1/1 of document 1467/1509
# Embedded chunk 1/1 of document 1468/1509
# Embedded chunk 1/1 of document 1469/1509
# Embedded chunk 1/1 of document 1470/1509
# Embedded chunk 1/1 of document 1471/1509
# Embedded chunk 1/1 of document 1472/1509
# Embedded chunk 1/1 of document 1473/1509
# Embedded chunk 1/1 of document 1474/1509
# Embedded chunk 1/1 of document 1475/1509
# Embedded chunk 1/1 of document 1476/1509
# Embedded chunk 1/1 of document 1477/1509
# Embedded chunk 1/1 of document 1478/1509
# Embedded chunk 1/1 of document 1479/1509
# Embedded chunk 1/1 of document 1480/1509
# Embedded chunk 1/1 of document 1481/1509
# Embedded chunk 1/1 of document 1482/1509
# Embedded chunk 1/1 of document 1483/1509
# Embedded chunk 1/1 of document 1484/1509
# Embedded chunk 1/1 of document 1485/1509
# Embedded chunk 1/1 of document 1486/1509
# Embedded chunk 1/1 of document 1487/1509
# Embedded chunk 1/1 of document 1488/1509
# Embedded chunk 1/1 of document 1489/1509
# Embedded chunk 1/1 of document 1490/1509
# Embedded chunk 1/1 of document 1491/1509
# Embedded chunk 1/1 of document 1492/1509
# Embedded chunk 1/1 of document 1493/1509
# Embedded chunk 1/1 of document 1494/1509
# Embedded chunk 1/1 of document 1495/1509
# Embedded chunk 1/1 of document 1496/1509
# Embedded chunk 1/1 of document 1497/1509
# Embedded chunk 1/1 of document 1498/1509
# Embedded chunk 1/1 of document 1499/1509
# Embedded chunk 1/1 of document 1500/1509
# Embedded chunk 1/1 of document 1501/1509
# Embedded chunk 1/1 of document 1502/1509
# Embedded chunk 1/5 of document 1503/1509
# Embedded chunk 2/5 of document 1503/1509
# Embedded chunk 3/5 of document 1503/1509
# Embedded chunk 4/5 of document 1503/1509
# Embedded chunk 5/5 of document 1503/1509
# Embedded chunk 1/2 of document 1504/1509
# Embedded chunk 2/2 of document 1504/1509
# Embedded chunk 1/1 of document 1505/1509
# Embedded chunk 1/1 of document 1506/1509
# Embedded chunk 1/1 of document 1507/1509
# Embedded chunk 1/2 of document 1508/1509
# Embedded chunk 2/2 of document 1508/1509
# Embedded chunk 1/1 of document 1509/1509
# All document embeddings have size: 1024

# %%
print(all_categories[:10])
# Out:
# ['Supreme Court Jurisprudence', 'Supreme Court Jurisprudence', 'Supreme Court Jurisprudence', 'Supreme Court Jurisprudence', 'Supreme Court Jurisprudence', 'Supreme Court Jurisprudence', 'Supreme Court Jurisprudence', 'Supreme Court Jurisprudence', 'Supreme Court Jurisprudence', 'Supreme Court Jurisprudence']

# %%
embeddings_df.to_csv('embeddings_with_doc_indices.csv', index=False)
print('Embeddings DataFrame saved to CSV file.')
# Out:
# Embeddings DataFrame saved to CSV file.

# %% [markdown]
# ## UMAP without Query

# %% [markdown]
# ### Euclidean Distance (Default)

# %%
all_embeddings_np = np.vstack(embeddings_df['embedding'].values)

# Fit and transform the embeddings using UMAP
umap_model = umap.UMAP(n_neighbors=15, min_dist=0.1, n_components=2, random_state=42)
umap_embeddings = umap_model.fit_transform(all_embeddings_np)

# Create a DataFrame with UMAP embeddings and categories
umap_df = pd.DataFrame(umap_embeddings, columns=['dim1', 'dim2'])
umap_df['category'] = embeddings_df['category']

# Plot the UMAP embeddings with categories
plt.figure(figsize=(12, 8))
sns.scatterplot(x='dim1', y='dim2', hue='category', data=umap_df, palette='viridis', alpha=0.7)
plt.title('UMAP Visualization of Document Embeddings')
plt.xlabel('UMAP Dimension 1')
plt.ylabel('UMAP Dimension 2')
plt.legend(loc='best', title='Category')

# Save the plot as an image
output_dir = '.'  # You can specify your desired directory here
plot_path = os.path.join(output_dir, 'euclidean_umap_visualization.png')
plt.savefig(plot_path)
plt.close()

print(f'Plot saved to {plot_path}')
# Out:
# D:\Anaconda3Updated\envs\pytorch_env\lib\site-packages\umap\umap_.py:1945: UserWarning:
#
# n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
# Plot saved to .\euclidean_umap_visualization.png

# %%
all_embeddings_np = np.vstack(embeddings_df['embedding'].values)

# Fit and transform the embeddings using UMAP for 3D visualization
umap_model = umap.UMAP(n_neighbors=15, min_dist=0.1, n_components=3, random_state=42)
umap_embeddings = umap_model.fit_transform(all_embeddings_np)

# Create a DataFrame with UMAP embeddings and categories
umap_df = pd.DataFrame(umap_embeddings, columns=['dim1', 'dim2', 'dim3'])
umap_df['category'] = embeddings_df['category']

# Create a directory to save frames
output_dir = './umap_frames'
os.makedirs(output_dir, exist_ok=True)

# Generate frames for the GIF
angles = np.linspace(0, 360, 60)  # 60 frames for a full rotation
filenames = []

for angle in angles:
    fig = plt.figure(figsize=(12, 8))
    ax = fig.add_subplot(111, projection='3d')
    sc = ax.scatter(umap_df['dim1'], umap_df['dim2'], umap_df['dim3'], c=umap_df['category'].astype('category').cat.codes, cmap='viridis', alpha=0.7)
    
    # Add legend
    handles, labels = sc.legend_elements()
    legend = ax.legend(handles, umap_df['category'].astype('category').cat.categories, title='Category')
    
    ax.set_title('3D UMAP Visualization of Document Embeddings')
    ax.set_xlabel('UMAP Dimension 1')
    ax.set_ylabel('UMAP Dimension 2')
    ax.set_zlabel('UMAP Dimension 3')
    ax.view_init(30, angle)  # Rotate the view

    # Save the frame
    filename = os.path.join(output_dir, f'frame_{int(angle):03d}.png')
    plt.savefig(filename)
    plt.close()
    filenames.append(filename)

# Create a GIF from the saved frames
gif_path = os.path.join(output_dir, 'euclidean_umap_visualization_3d.gif')
with imageio.get_writer(gif_path, mode='I', duration=0.1) as writer:
    for filename in filenames:
        image = imageio.imread(filename)
        writer.append_data(image)

# Clean up (optional): Remove the individual frame files
for filename in filenames:
    os.remove(filename)

print(f'GIF saved to {gif_path}')
# Out:
# D:\Anaconda3Updated\envs\pytorch_env\lib\site-packages\umap\umap_.py:1945: UserWarning:
#
# n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
# GIF saved to ./umap_frames\euclidean_umap_visualization_3d.gif

# %% [markdown]
# ### Cosine Similarity

# %%
all_embeddings_np = np.vstack(embeddings_df['embedding'].values)

# Fit and transform the embeddings using UMAP
umap_model = umap.UMAP(n_neighbors=15, min_dist=0.1, n_components=2, random_state=42,metric='cosine')
umap_embeddings = umap_model.fit_transform(all_embeddings_np)

# Create a DataFrame with UMAP embeddings and categories
umap_df = pd.DataFrame(umap_embeddings, columns=['dim1', 'dim2'])
umap_df['category'] = embeddings_df['category']

# Plot the UMAP embeddings with categories
plt.figure(figsize=(12, 8))
sns.scatterplot(x='dim1', y='dim2', hue='category', data=umap_df, palette='viridis', alpha=0.7)
plt.title('UMAP Visualization of Document Embeddings')
plt.xlabel('UMAP Dimension 1')
plt.ylabel('UMAP Dimension 2')
plt.legend(loc='best', title='Category')

# Save the plot as an image
output_dir = '.'  # You can specify your desired directory here
plot_path = os.path.join(output_dir, 'cosine_umap_visualization.png')
plt.savefig(plot_path)
plt.close()

print(f'Plot saved to {plot_path}')
# Out:
# D:\Anaconda3Updated\envs\pytorch_env\lib\site-packages\umap\umap_.py:1945: UserWarning:
#
# n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
# Plot saved to .\cosine_umap_visualization.png

# %%
all_embeddings_np = np.vstack(embeddings_df['embedding'].values)

# Fit and transform the embeddings using UMAP for 3D visualization
umap_model = umap.UMAP(n_neighbors=15, min_dist=0.1, n_components=3, random_state=42,metric='cosine')
umap_embeddings = umap_model.fit_transform(all_embeddings_np)

# Create a DataFrame with UMAP embeddings and categories
umap_df = pd.DataFrame(umap_embeddings, columns=['dim1', 'dim2', 'dim3'])
umap_df['category'] = embeddings_df['category']

# Create a directory to save frames
output_dir = './umap_frames'
os.makedirs(output_dir, exist_ok=True)

# Generate frames for the GIF
angles = np.linspace(0, 360, 60)  # 60 frames for a full rotation
filenames = []

for angle in angles:
    fig = plt.figure(figsize=(12, 8))
    ax = fig.add_subplot(111, projection='3d')
    sc = ax.scatter(umap_df['dim1'], umap_df['dim2'], umap_df['dim3'], c=umap_df['category'].astype('category').cat.codes, cmap='viridis', alpha=0.7)
    
    # Add legend
    handles, labels = sc.legend_elements()
    legend = ax.legend(handles, umap_df['category'].astype('category').cat.categories, title='Category')
    
    ax.set_title('3D UMAP Visualization of Document Embeddings')
    ax.set_xlabel('UMAP Dimension 1')
    ax.set_ylabel('UMAP Dimension 2')
    ax.set_zlabel('UMAP Dimension 3')
    ax.view_init(30, angle)  # Rotate the view

    # Save the frame
    filename = os.path.join(output_dir, f'frame_{int(angle):03d}.png')
    plt.savefig(filename)
    plt.close()
    filenames.append(filename)

# Create a GIF from the saved frames
gif_path = os.path.join(output_dir, 'cosine_umap_visualization_3d.gif')
with imageio.get_writer(gif_path, mode='I', duration=0.1) as writer:
    for filename in filenames:
        image = imageio.imread(filename)
        writer.append_data(image)

# Clean up (optional): Remove the individual frame files
for filename in filenames:
    os.remove(filename)

print(f'GIF saved to {gif_path}')
# Out:
# D:\Anaconda3Updated\envs\pytorch_env\lib\site-packages\umap\umap_.py:1945: UserWarning:
#
# n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
# GIF saved to ./umap_frames\cosine_umap_visualization_3d.gif

# %% [markdown]
# ## UMAP with Query

# %%
query = "The court found the defendant guilty of murder in the first degree, citing overwhelming evidence of premeditation and intent. The prosecution presented a compelling case, including eyewitness testimony and forensic evidence linking the defendant to the crime scene."
query_embedding = model.encode(query, convert_to_tensor=True, device=device)
query_embedding = query_embedding.cpu().numpy()

embeddings_np = np.array(embeddings_df['embedding'].tolist())
print(embeddings_np.shape)
all_embeddings_np = np.vstack([embeddings_np, query_embedding])
print(all_embeddings_np.shape)
# Out:
# (10135, 1024)
# (10136, 1024)

# %%
umap_model = umap.UMAP(n_neighbors=15, min_dist=0.1, n_components=2, random_state=42)
umap_embeddings = umap_model.fit_transform(all_embeddings_np)

# Create a DataFrame with UMAP embeddings and categories
umap_df = pd.DataFrame(umap_embeddings, columns=['dim1', 'dim2'])
# Ensure the category list is properly constructed
categories = embeddings_df['category'].tolist()
categories.append('Query')  # Add 'Query' with capital Q
umap_df['category'] = categories

# Plot the UMAP embeddings with categories, excluding 'Query' for now
plt.figure(figsize=(12, 8))
non_query_points = umap_df[umap_df['category'] != 'Query']
sns.scatterplot(x='dim1', y='dim2', hue='category', data=non_query_points, palette='viridis', alpha=0.7)

# Highlight the query embedding separately to avoid duplicate legend entries
query_point = umap_df[umap_df['category'] == 'Query']
plt.scatter(query_point['dim1'], query_point['dim2'], color='red', edgecolor='black', s=100, label='Query')

plt.title('UMAP Visualization of Document Embeddings')
plt.xlabel('UMAP Dimension 1')
plt.ylabel('UMAP Dimension 2')
plt.legend(loc='best', title='Category')

# Save the plot as an image
output_dir = '.'  # You can specify your desired directory here
plot_path = os.path.join(output_dir, 'euclidean_query_umap_visualization.png')
plt.savefig(plot_path)
plt.close()

print(f'Plot saved to {plot_path}')
# Out:
# D:\Anaconda3Updated\envs\pytorch_env\lib\site-packages\umap\umap_.py:1945: UserWarning:
#
# n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
# Plot saved to .\euclidean_query_umap_visualization.png

# %%
query = "The court found the defendant guilty of murder in the first degree, citing overwhelming evidence of premeditation and intent. The prosecution presented a compelling case, including eyewitness testimony and forensic evidence linking the defendant to the crime scene."
query_embedding = model.encode(query, convert_to_tensor=True, device=device)
query_embedding = query_embedding.cpu().numpy()

embeddings_np = np.array(embeddings_df['embedding'].tolist())
print(embeddings_np.shape)
all_embeddings_np = np.vstack([embeddings_np, query_embedding])
print(all_embeddings_np.shape)
# Out:
# (10135, 1024)
# (10136, 1024)

# %%
import imageio.v2 as imageio  # Use imageio.v2 to avoid deprecation warning
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.cm import viridis
from matplotlib.colors import Normalize

umap_model = umap.UMAP(n_neighbors=15, min_dist=0.1, n_components=3, random_state=42)
umap_embeddings = umap_model.fit_transform(all_embeddings_np)

# Create a DataFrame with UMAP embeddings and categories
umap_df = pd.DataFrame(umap_embeddings, columns=['dim1', 'dim2', 'dim3'])
categories = embeddings_df['category'].tolist()
categories.append('Query')  # Add 'Query' with capital Q
umap_df['category'] = categories

# Get the query point coordinates
query_point = umap_df[umap_df['category'] == 'Query']
query_x, query_y, query_z = query_point.iloc[0][['dim1', 'dim2', 'dim3']]

# Normalize the categories for color mapping
unique_categories = umap_df['category'].unique()
norm = Normalize(vmin=0, vmax=len(unique_categories) - 2)
cmap = plt.get_cmap('viridis')

# Generate GIF frames by zooming in and out
frames = []
frame_paths = []  # To store paths of frame images
zoom_levels = np.linspace(0.1, 4, 30).tolist() + np.linspace(4, 0.1, 30).tolist()

for zoom in zoom_levels:
    fig = plt.figure(figsize=(10, 7))
    ax = fig.add_subplot(111, projection='3d')
    
    # Plot non-query points with colors from viridis colormap
    non_query_points = umap_df[umap_df['category'] != 'Query']
    for idx, category in enumerate(non_query_points['category'].unique()):
        category_points = non_query_points[non_query_points['category'] == category]
        color = cmap(norm(idx))
        ax.scatter(category_points['dim1'], category_points['dim2'], category_points['dim3'],
                   label=category, s=20, alpha=0.7, color=color)
    
    # Plot the query point
    ax.scatter(query_x, query_y, query_z, color='red', edgecolor='black', s=100, label='Query')
    
    # Set labels and title
    ax.set_xlabel('UMAP Dimension 1')
    ax.set_ylabel('UMAP Dimension 2')
    ax.set_zlabel('UMAP Dimension 3')
    ax.set_title('3D UMAP Visualization of Document Embeddings')
    ax.legend(loc='best', title='Category')
    
    # Adjust the camera position to zoom in and out on the query point
    ax.set_xlim([query_x - zoom, query_x + zoom])
    ax.set_ylim([query_y - zoom, query_y + zoom])
    ax.set_zlim([query_z - zoom, query_z + zoom])
    
    # Save frame
    frame_path = os.path.join(output_dir, f'frame_{zoom:.2f}.png')
    plt.savefig(frame_path)
    frame_paths.append(frame_path)
    frames.append(imageio.imread(frame_path))
    plt.close()

# Save the GIF
gif_path = os.path.join(output_dir, 'euclidean_query_3d_umap_zoom.gif')
imageio.mimsave(gif_path, frames, fps=10)

# Clean up frame images

print(f'GIF saved to {gif_path}')
# Out:
# D:\Anaconda3Updated\envs\pytorch_env\lib\site-packages\umap\umap_.py:1945: UserWarning:
#
# n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
# GIF saved to .\euclidean_query_3d_umap_zoom.gif

# %% [markdown]
# ### Cosine Similarity

# %%
query = "The court found the defendant guilty of murder in the first degree, citing overwhelming evidence of premeditation and intent. The prosecution presented a compelling case, including eyewitness testimony and forensic evidence linking the defendant to the crime scene."
query_embedding = model.encode(query, convert_to_tensor=True, device=device)
query_embedding = query_embedding.cpu().numpy()

embeddings_np = np.array(embeddings_df['embedding'].tolist())
print(embeddings_np.shape)
all_embeddings_np = np.vstack([embeddings_np, query_embedding])
print(all_embeddings_np.shape)
# Out:
# (10135, 1024)
# (10136, 1024)

# %%
umap_model = umap.UMAP(n_neighbors=15, min_dist=0.1, n_components=2, random_state=42,metric='cosine')
umap_embeddings = umap_model.fit_transform(all_embeddings_np)

# Create a DataFrame with UMAP embeddings and categories
umap_df = pd.DataFrame(umap_embeddings, columns=['dim1', 'dim2'])
# Ensure the category list is properly constructed
categories = embeddings_df['category'].tolist()
categories.append('Query')  # Add 'Query' with capital Q
umap_df['category'] = categories

# Plot the UMAP embeddings with categories, excluding 'Query' for now
plt.figure(figsize=(12, 8))
non_query_points = umap_df[umap_df['category'] != 'Query']
sns.scatterplot(x='dim1', y='dim2', hue='category', data=non_query_points, palette='viridis', alpha=0.7)

# Highlight the query embedding separately to avoid duplicate legend entries
query_point = umap_df[umap_df['category'] == 'Query']
plt.scatter(query_point['dim1'], query_point['dim2'], color='red', edgecolor='black', s=100, label='Query')

plt.title('UMAP Visualization of Document Embeddings')
plt.xlabel('UMAP Dimension 1')
plt.ylabel('UMAP Dimension 2')
plt.legend(loc='best', title='Category')

# Save the plot as an image
output_dir = '.'  # You can specify your desired directory here
plot_path = os.path.join(output_dir, 'cosine_query_umap_visualization.png')
plt.savefig(plot_path)
plt.close()

print(f'Plot saved to {plot_path}')
# Out:
# D:\Anaconda3Updated\envs\pytorch_env\lib\site-packages\umap\umap_.py:1945: UserWarning:
#
# n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
# Plot saved to .\cosine_query_umap_visualization.png

# %%
query = "The court found the defendant guilty of murder in the first degree, citing overwhelming evidence of premeditation and intent. The prosecution presented a compelling case, including eyewitness testimony and forensic evidence linking the defendant to the crime scene."
query_embedding = model.encode(query, convert_to_tensor=True, device=device)
query_embedding = query_embedding.cpu().numpy()

embeddings_np = np.array(embeddings_df['embedding'].tolist())
print(embeddings_np.shape)
all_embeddings_np = np.vstack([embeddings_np, query_embedding])
print(all_embeddings_np.shape)
# Out:
# (10135, 1024)
# (10136, 1024)

# %%
import imageio.v2 as imageio  # Use imageio.v2 to avoid deprecation warning
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.cm import viridis
from matplotlib.colors import Normalize

umap_model = umap.UMAP(n_neighbors=15, min_dist=0.1, n_components=3, random_state=42,metric='cosine')
umap_embeddings = umap_model.fit_transform(all_embeddings_np)

# Create a DataFrame with UMAP embeddings and categories
umap_df = pd.DataFrame(umap_embeddings, columns=['dim1', 'dim2', 'dim3'])
categories = embeddings_df['category'].tolist()
categories.append('Query')  # Add 'Query' with capital Q
umap_df['category'] = categories

# Get the query point coordinates
query_point = umap_df[umap_df['category'] == 'Query']
query_x, query_y, query_z = query_point.iloc[0][['dim1', 'dim2', 'dim3']]

# Normalize the categories for color mapping
unique_categories = umap_df['category'].unique()
norm = Normalize(vmin=0, vmax=len(unique_categories) - 2)
cmap = plt.get_cmap('viridis')

# Generate GIF frames by zooming in and out
frames = []
frame_paths = []  # To store paths of frame images
zoom_levels = np.linspace(0.1, 4, 30).tolist() + np.linspace(4, 0.1, 30).tolist()

for zoom in zoom_levels:
    fig = plt.figure(figsize=(10, 7))
    ax = fig.add_subplot(111, projection='3d')
    
    # Plot non-query points with colors from viridis colormap
    non_query_points = umap_df[umap_df['category'] != 'Query']
    for idx, category in enumerate(non_query_points['category'].unique()):
        category_points = non_query_points[non_query_points['category'] == category]
        color = cmap(norm(idx))
        ax.scatter(category_points['dim1'], category_points['dim2'], category_points['dim3'],
                   label=category, s=20, alpha=0.7, color=color)
    
    # Plot the query point
    ax.scatter(query_x, query_y, query_z, color='red', edgecolor='black', s=100, label='Query')
    
    # Set labels and title
    ax.set_xlabel('UMAP Dimension 1')
    ax.set_ylabel('UMAP Dimension 2')
    ax.set_zlabel('UMAP Dimension 3')
    ax.set_title('3D UMAP Visualization of Document Embeddings')
    ax.legend(loc='best', title='Category')
    
    # Adjust the camera position to zoom in and out on the query point
    ax.set_xlim([query_x - zoom, query_x + zoom])
    ax.set_ylim([query_y - zoom, query_y + zoom])
    ax.set_zlim([query_z - zoom, query_z + zoom])
    
    # Save frame
    frame_path = os.path.join(output_dir, f'frame_{zoom:.2f}.png')
    plt.savefig(frame_path)
    frame_paths.append(frame_path)
    frames.append(imageio.imread(frame_path))
    plt.close()

# Save the GIF
gif_path = os.path.join(output_dir, 'cosine_query_3d_umap_zoom.gif')
imageio.mimsave(gif_path, frames, fps=10)

# Clean up frame images

print(f'GIF saved to {gif_path}')
# Out:
# D:\Anaconda3Updated\envs\pytorch_env\lib\site-packages\umap\umap_.py:1945: UserWarning:
#
# n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
# GIF saved to .\cosine_query_3d_umap_zoom.gif
